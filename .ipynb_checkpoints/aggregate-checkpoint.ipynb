# %%
import numpy as np
import pandas as pd
import statistics

# %% [markdown]
# # Q vs Q - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_none/q_vs_q.csv")
    df_shock_a = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_a/q_vs_q_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_b/q_vs_q_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_c/q_vs_q_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# -- Mean --
# 1.68	1.68
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.45	0.45
# 0.47	0.44
# 0.45	0.45
# 0.45	0.45
# 0.46	0.46
# 0.45	0.45
# 0.44	0.45
# -- Mean --
# 0.45	0.45
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.46
# 0.46	0.47
# 0.46	0.46
# 0.46	0.46
# 0.47	0.47
# 0.46	0.46
# 0.46	0.46
# -- Mean --
# 0.46	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.68	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# -- Mean --
# 1.69	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -1.56	-1.57
# -1.32	-1.37
# -1.36	-1.31
# -1.17	-1.18
# -1.24	-1.25
# -1.38	-1.34
# -1.22	-1.25
# -- Mean --
# -1.32	-1.32
# -- St. Dev --
# 0.13	0.13

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.39	-0.39
# -0.36	-0.34
# -0.37	-0.38
# -0.33	-0.32
# -0.35	-0.34
# -0.37	-0.38
# -0.33	-0.33
# -- Mean --
# -0.36	-0.35
# -- St. Dev --
# 0.02	0.03

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# 1.68	1.68
# -- Mean --
# 1.68	1.68
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.3	0.28
# 0.26	0.25
# 0.3	0.29
# 0.27	0.26
# 0.31	0.31
# 0.29	0.26
# 0.31	0.26
# -- Mean --
# 0.29	0.27
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.36	0.36
# 0.35	0.34
# 0.35	0.36
# 0.35	0.36
# 0.36	0.36
# 0.36	0.36
# 0.35	0.36
# -- Mean --
# 0.35	0.36
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# -- Mean --
# 1.69	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.67	-2.63
# -2.9	-2.9
# -2.57	-2.59
# -2.87	-2.74
# -2.88	-2.95
# -2.48	-2.64
# -2.73	-2.78
# -- Mean --
# -2.73	-2.75
# -- St. Dev --
# 0.16	0.14

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.79	-0.79
# -0.82	-0.81
# -0.77	-0.76
# -0.8	-0.8
# -0.83	-0.83
# -0.79	-0.78
# -0.82	-0.82
# -- Mean --
# -0.8	-0.8
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# # Q vs Q - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_none/q_vs_q.csv")
    df_shock_a = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_a/q_vs_q_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_b/q_vs_q_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_c/q_vs_q_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# 1.12	1.13
# 1.12	1.12
# -- Mean --
# 1.12	1.12
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.46
# 0.46	0.44
# 0.45	0.46
# 0.45	0.45
# 0.45	0.46
# 0.47	0.45
# 0.45	0.46
# -- Mean --
# 0.46	0.45
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.49
# 0.48	0.49
# 0.49	0.49
# 0.49	0.49
# 0.5	0.49
# 0.49	0.5
# 0.49	0.49
# -- Mean --
# 0.49	0.49
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.47
# 0.49	0.47
# 0.47	0.48
# 0.48	0.48
# 0.5	0.47
# 0.49	0.47
# 0.46	0.5
# -- Mean --
# 0.48	0.48
# -- St. Dev --
# 0.02	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.51
# 0.51	0.51
# 0.51	0.51
# 0.51	0.51
# 0.51	0.52
# 0.51	0.51
# 0.51	0.51
# -- Mean --
# 0.51	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.12
# 1.12	1.13
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# 1.12	1.12
# -- Mean --
# 1.12	1.12
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.48
# 0.46	0.46
# 0.5	0.42
# 0.51	0.39
# 0.45	0.47
# 0.49	0.43
# 0.43	0.48
# -- Mean --
# 0.47	0.45
# -- St. Dev --
# 0.03	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.5
# 0.49	0.5
# 0.49	0.5
# 0.49	0.49
# 0.5	0.5
# 0.5	0.5
# 0.49	0.49
# -- Mean --
# 0.49	0.5
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.43	0.55
# 0.61	0.37
# 0.49	0.5
# 0.46	0.51
# 0.41	0.57
# 0.59	0.39
# 0.5	0.49
# -- Mean --
# 0.5	0.48
# -- St. Dev --
# 0.08	0.08

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.51
# 0.51	0.51
# 0.52	0.52
# 0.51	0.51
# 0.51	0.52
# 0.52	0.52
# 0.52	0.52
# -- Mean --
# 0.51	0.52
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# # Q vs Q - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_none/q_vs_q.csv")
    df_shock_a = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_a/q_vs_q_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_b/q_vs_q_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_q/results/run_{i}/shock_c/q_vs_q_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# -- Mean --
# 0.46	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# -- Mean --
# 0.04	0.04
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.49
# 0.49	0.49
# 0.5	0.5
# 0.49	0.5
# 0.49	0.49
# 0.49	0.5
# 0.5	0.49
# -- Mean --
# 0.49	0.49
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.46
# 0.46	0.47
# 0.46	0.47
# 0.47	0.47
# 0.47	0.46
# 0.47	0.46
# 0.47	0.47
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.7	0.68
# 0.7	0.7
# 0.71	0.71
# 0.71	0.71
# 0.73	0.67
# 0.67	0.72
# 0.7	0.7
# -- Mean --
# 0.7	0.7
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.51
# 0.51	0.52
# 0.51	0.51
# 0.51	0.51
# 0.51	0.51
# 0.51	0.51
# 0.51	0.51
# -- Mean --
# 0.51	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# -- Mean --
# 0.46	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.06	0.01
# 0.1	-0.0
# 0.11	0.03
# 0.0	0.11
# 0.07	0.04
# 0.07	0.06
# 0.01	-0.01
# -- Mean --
# 0.04	0.03
# -- St. Dev --
# 0.06	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.5
# 0.5	0.5
# 0.5	0.5
# 0.49	0.5
# 0.5	0.5
# 0.51	0.5
# 0.5	0.49
# -- Mean --
# 0.5	0.5
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.47
# 0.46	0.46
# 0.47	0.47
# 0.47	0.47
# 0.46	0.47
# 0.47	0.47
# 0.47	0.47
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.38	1.17
# 1.22	1.16
# 1.18	1.28
# 1.25	1.16
# 1.2	1.21
# 1.29	1.23
# 1.25	1.14
# -- Mean --
# 1.25	1.19
# -- St. Dev --
# 0.07	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.52
# 0.51	0.51
# 0.51	0.52
# 0.51	0.51
# 0.51	0.51
# 0.51	0.52
# 0.51	0.52
# -- Mean --
# 0.51	0.52
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# # Q vs PSO - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_none/q_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_a/q_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_b/q_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_c/q_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.69
# 1.67	1.69
# 1.66	1.69
# 1.66	1.69
# 1.67	1.69
# 1.66	1.69
# 1.66	1.69
# -- Mean --
# 1.66	1.69
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.55	0.56
# 0.54	0.55
# 0.54	0.52
# 0.55	0.5
# 0.54	0.56
# 0.55	0.53
# 0.54	0.53
# -- Mean --
# 0.54	0.54
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.43	0.48
# 0.43	0.48
# 0.41	0.48
# 0.4	0.48
# 0.43	0.48
# 0.42	0.48
# 0.42	0.48
# -- Mean --
# 0.42	0.48
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.66	1.69
# 1.67	1.69
# 1.67	1.69
# 1.66	1.69
# 1.66	1.69
# 1.67	1.69
# 1.67	1.69
# -- Mean --
# 1.67	1.69
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -1.14	-1.1
# -1.11	-1.01
# -0.94	-0.91
# -1.03	-1.0
# -1.22	-1.19
# -1.2	-1.12
# -1.02	-1.04
# -- Mean --
# -1.09	-1.05
# -- St. Dev --
# 0.1	0.09

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.45	-0.37
# -0.44	-0.37
# -0.4	-0.33
# -0.42	-0.34
# -0.48	-0.39
# -0.46	-0.38
# -0.43	-0.35
# -- Mean --
# -0.44	-0.36
# -- St. Dev --
# 0.03	0.02

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.65	1.69
# 1.66	1.69
# 1.66	1.69
# 1.66	1.69
# 1.66	1.69
# 1.66	1.69
# 1.65	1.69
# -- Mean --
# 1.66	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.41	0.35
# 0.36	0.37
# 0.39	0.39
# 0.38	0.32
# 0.39	0.37
# 0.41	0.33
# 0.37	0.31
# -- Mean --
# 0.39	0.35
# -- St. Dev --
# 0.02	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.29	0.38
# 0.3	0.37
# 0.3	0.37
# 0.29	0.37
# 0.29	0.37
# 0.3	0.37
# 0.28	0.37
# -- Mean --
# 0.29	0.37
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.69
# 1.67	1.69
# 1.66	1.69
# 1.67	1.69
# 1.67	1.69
# 1.67	1.69
# 1.66	1.69
# -- Mean --
# 1.67	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.88	-3.01
# -2.31	-2.24
# -2.65	-2.29
# -2.62	-2.36
# -2.61	-2.74
# -2.08	-2.21
# -2.36	-2.16
# -- Mean --
# -2.5	-2.43
# -- St. Dev --
# 0.27	0.32

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.97	-0.88
# -0.88	-0.8
# -0.92	-0.82
# -0.9	-0.81
# -0.95	-0.87
# -0.81	-0.73
# -0.85	-0.76
# -- Mean --
# -0.9	-0.81
# -- St. Dev --
# 0.06	0.05

# %% [markdown]
# # Q vs PSO - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_none/q_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_a/q_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_b/q_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_c/q_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# -- Mean --
# 1.12	1.14
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.54	0.48
# 0.54	0.48
# 0.54	0.46
# 0.54	0.48
# 0.54	0.48
# 0.54	0.46
# 0.54	0.46
# -- Mean --
# 0.54	0.47
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.57
# 0.49	0.57
# 0.48	0.57
# 0.49	0.57
# 0.49	0.57
# 0.48	0.57
# 0.47	0.57
# -- Mean --
# 0.48	0.57
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# -- Mean --
# 1.13	1.14
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.56	0.49
# 0.53	0.51
# 0.54	0.51
# 0.53	0.54
# 0.53	0.52
# 0.53	0.52
# 0.54	0.52
# -- Mean --
# 0.54	0.52
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.57
# 0.5	0.57
# 0.52	0.57
# 0.53	0.57
# 0.51	0.57
# 0.52	0.57
# 0.51	0.57
# -- Mean --
# 0.51	0.57
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.11	1.14
# 1.11	1.14
# 1.11	1.14
# 1.12	1.14
# 1.12	1.14
# 1.12	1.14
# 1.11	1.14
# -- Mean --
# 1.11	1.14
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.58	0.4
# 0.53	0.46
# 0.52	0.45
# 0.53	0.47
# 0.54	0.48
# 0.51	0.49
# 0.56	0.41
# -- Mean --
# 0.54	0.45
# -- St. Dev --
# 0.02	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.45	0.57
# 0.46	0.57
# 0.45	0.57
# 0.47	0.57
# 0.49	0.57
# 0.48	0.57
# 0.45	0.57
# -- Mean --
# 0.46	0.57
# -- St. Dev --
# 0.02	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# -- Mean --
# 1.13	1.14
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.58
# 0.48	0.58
# 0.56	0.5
# 0.64	0.41
# 0.48	0.58
# 0.4	0.66
# 0.5	0.56
# -- Mean --
# 0.5	0.55
# -- St. Dev --
# 0.08	0.08

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.57
# 0.52	0.57
# 0.52	0.57
# 0.52	0.57
# 0.52	0.57
# 0.52	0.57
# 0.52	0.57
# -- Mean --
# 0.52	0.57
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# # Q vs PSO - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_none/q_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_a/q_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_b/q_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_pso/results/run_{i}/shock_c/q_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# -- Mean --
# 0.46	0.44
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.01	0.07
# -0.01	0.07
# -0.01	0.07
# -0.01	0.07
# -0.01	0.07
# -0.01	0.07
# -0.01	0.07
# -- Mean --
# -0.01	0.07
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.16
# 0.46	0.16
# 0.5	0.16
# 0.48	0.16
# 0.49	0.16
# 0.49	0.16
# 0.46	0.16
# -- Mean --
# 0.48	0.16
# -- St. Dev --
# 0.02	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# -- Mean --
# 0.47	0.44
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.68	0.65
# 0.69	0.64
# 0.65	0.64
# 0.64	0.65
# 0.64	0.66
# 0.66	0.65
# 0.66	0.67
# -- Mean --
# 0.66	0.65
# -- St. Dev --
# 0.02	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.16
# 0.52	0.16
# 0.52	0.16
# 0.52	0.16
# 0.51	0.16
# 0.53	0.16
# 0.52	0.16
# -- Mean --
# 0.52	0.16
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# 0.46	0.44
# -- Mean --
# 0.46	0.44
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.02	0.1
# 0.01	0.05
# 0.0	0.03
# 0.01	0.16
# -0.03	0.11
# -0.03	0.07
# -0.03	0.05
# -- Mean --
# -0.01	0.08
# -- St. Dev --
# 0.02	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.16
# 0.46	0.16
# 0.49	0.16
# 0.47	0.16
# 0.46	0.16
# 0.44	0.16
# 0.47	0.16
# -- Mean --
# 0.47	0.16
# -- St. Dev --
# 0.02	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# 0.47	0.44
# -- Mean --
# 0.47	0.44
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.4	1.08
# 1.1	1.19
# 1.16	1.22
# 1.28	1.09
# 1.16	1.22
# 1.17	1.16
# 1.31	1.13
# -- Mean --
# 1.23	1.16
# -- St. Dev --
# 0.11	0.06

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.16
# 0.52	0.16
# 0.51	0.16
# 0.53	0.16
# 0.52	0.16
# 0.53	0.16
# 0.51	0.16
# -- Mean --
# 0.52	0.16
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# # Q vs DQN - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_none/q_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_a/q_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_b/q_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_c/q_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 4], df_shock_none.iat[0, 5]))
    deltas["shock_a"].append((df_shock_a.iat[0, 4], df_shock_a.iat[0, 5]))
    deltas["shock_b"].append((df_shock_b.iat[0, 4], df_shock_b.iat[0, 5]))
    deltas["shock_c"].append((df_shock_c.iat[0, 4], df_shock_c.iat[0, 5]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 6], df_shock_none.iat[0, 7]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 6], df_shock_a.iat[0, 7]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 6], df_shock_b.iat[0, 7]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 6], df_shock_c.iat[0, 7]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# -- Mean --
# 1.68	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.43
# 0.49	0.44
# 0.49	0.44
# 0.49	0.44
# 0.49	0.44
# 0.49	0.45
# 0.5	0.43
# -- Mean --
# 0.49	0.44
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.49
# 0.46	0.48
# 0.46	0.48
# 0.46	0.49
# 0.46	0.49
# 0.47	0.49
# 0.46	0.48
# -- Mean --
# 0.46	0.49
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# -- Mean --
# 1.69	1.7
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -1.39	-1.53
# -1.33	-1.45
# -1.34	-1.45
# -1.08	-1.27
# -1.09	-1.26
# -1.45	-1.62
# -1.28	-1.44
# -- Mean --
# -1.28	-1.43
# -- St. Dev --
# 0.14	0.13

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.38	-0.35
# -0.38	-0.35
# -0.38	-0.35
# -0.36	-0.33
# -0.34	-0.3
# -0.42	-0.38
# -0.38	-0.34
# -- Mean --
# -0.38	-0.34
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# 1.68	1.69
# -- Mean --
# 1.68	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.35	0.26
# 0.3	0.24
# 0.3	0.21
# 0.34	0.27
# 0.33	0.28
# 0.31	0.25
# 0.36	0.29
# -- Mean --
# 0.33	0.26
# -- St. Dev --
# 0.02	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.35	0.39
# 0.35	0.38
# 0.34	0.38
# 0.36	0.38
# 0.36	0.39
# 0.36	0.38
# 0.36	0.39
# -- Mean --
# 0.35	0.38
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# 1.69	1.7
# -- Mean --
# 1.69	1.7
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.47	-2.57
# -2.4	-2.52
# -2.23	-2.65
# -2.42	-2.33
# -2.52	-2.7
# -2.55	-2.93
# -2.49	-2.88
# -- Mean --
# -2.44	-2.65
# -- St. Dev --
# 0.11	0.21

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.74	-0.72
# -0.74	-0.7
# -0.75	-0.7
# -0.74	-0.72
# -0.77	-0.74
# -0.81	-0.76
# -0.82	-0.78
# -- Mean --
# -0.77	-0.73
# -- St. Dev --
# 0.03	0.03

# %% [markdown]
# # Q vs DQN - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_none/q_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_a/q_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_b/q_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_c/q_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 4], df_shock_none.iat[1, 5]))
    deltas["shock_a"].append((df_shock_a.iat[1, 4], df_shock_a.iat[1, 5]))
    deltas["shock_b"].append((df_shock_b.iat[1, 4], df_shock_b.iat[1, 5]))
    deltas["shock_c"].append((df_shock_c.iat[1, 4], df_shock_c.iat[1, 5]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 6], df_shock_none.iat[1, 7]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 6], df_shock_a.iat[1, 7]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 6], df_shock_b.iat[1, 7]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 6], df_shock_c.iat[1, 7]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.45
# 0.5	0.45
# 0.5	0.45
# 0.5	0.45
# 0.5	0.45
# 0.5	0.44
# 0.5	0.45
# -- Mean --
# 0.5	0.45
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.53
# 0.49	0.53
# 0.49	0.53
# 0.5	0.53
# 0.49	0.53
# 0.49	0.53
# 0.49	0.53
# -- Mean --
# 0.49	0.53
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.13
# 1.13	1.14
# 1.13	1.14
# 1.13	1.13
# 1.13	1.13
# 1.13	1.13
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.48
# 0.5	0.48
# 0.49	0.51
# 0.52	0.47
# 0.49	0.5
# 0.52	0.47
# 0.49	0.49
# -- Mean --
# 0.5	0.49
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.54
# 0.51	0.53
# 0.51	0.54
# 0.51	0.54
# 0.51	0.54
# 0.51	0.54
# 0.51	0.54
# -- Mean --
# 0.51	0.54
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# 1.12	1.13
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.47
# 0.47	0.48
# 0.5	0.45
# 0.52	0.43
# 0.51	0.44
# 0.48	0.46
# 0.52	0.43
# -- Mean --
# 0.5	0.45
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.53
# 0.5	0.53
# 0.49	0.53
# 0.49	0.53
# 0.49	0.53
# 0.49	0.53
# 0.49	0.53
# -- Mean --
# 0.49	0.53
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.14
# 1.13	1.13
# -- Mean --
# 1.13	1.14
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.57
# 0.5	0.5
# 0.54	0.46
# 0.49	0.52
# 0.5	0.52
# 0.51	0.49
# 0.49	0.52
# -- Mean --
# 0.5	0.51
# -- St. Dev --
# 0.03	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.54
# 0.51	0.54
# 0.51	0.54
# 0.52	0.54
# 0.52	0.55
# 0.51	0.54
# 0.52	0.54
# -- Mean --
# 0.52	0.54
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# # Q vs DQN - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_none/q_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_a/q_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_b/q_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./q_vs_dqn/results/run_{i}/shock_c/q_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 4], df_shock_none.iat[2, 5]))
    deltas["shock_a"].append((df_shock_a.iat[2, 4], df_shock_a.iat[2, 5]))
    deltas["shock_b"].append((df_shock_b.iat[2, 4], df_shock_b.iat[2, 5]))
    deltas["shock_c"].append((df_shock_c.iat[2, 4], df_shock_c.iat[2, 5]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 6], df_shock_none.iat[2, 7]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 6], df_shock_a.iat[2, 7]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 6], df_shock_b.iat[2, 7]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 6], df_shock_c.iat[2, 7]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.46
# 0.46	0.47
# -- Mean --
# 0.46	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# 0.04	0.04
# -- Mean --
# 0.04	0.04
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.52
# 0.49	0.51
# 0.49	0.51
# 0.49	0.51
# 0.5	0.51
# 0.5	0.51
# 0.49	0.51
# -- Mean --
# 0.49	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.47
# 0.47	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.47	0.47
# -- Mean --
# 0.46	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.68	0.67
# 0.75	0.66
# 0.69	0.74
# 0.67	0.73
# 0.68	0.78
# 0.73	0.71
# 0.69	0.73
# -- Mean --
# 0.7	0.72
# -- St. Dev --
# 0.03	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.52
# 0.51	0.52
# 0.51	0.52
# 0.51	0.52
# 0.51	0.52
# 0.51	0.53
# 0.52	0.52
# -- Mean --
# 0.51	0.52
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.46
# 0.46	0.47
# 0.46	0.47
# -- Mean --
# 0.46	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.12	0.08
# 0.1	0.02
# 0.04	0.03
# 0.04	0.03
# 0.08	0.08
# 0.07	0.04
# 0.1	0.02
# -- Mean --
# 0.08	0.04
# -- St. Dev --
# 0.03	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.51
# 0.49	0.52
# 0.5	0.51
# 0.5	0.51
# 0.49	0.51
# 0.5	0.51
# 0.5	0.51
# -- Mean --
# 0.5	0.51
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.47
# 0.46	0.47
# 0.47	0.47
# 0.46	0.47
# 0.47	0.47
# 0.46	0.47
# 0.47	0.47
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.34	1.12
# 1.32	1.22
# 1.2	1.26
# 1.33	1.06
# 1.39	1.01
# 1.18	1.21
# 1.21	1.25
# -- Mean --
# 1.28	1.16
# -- St. Dev --
# 0.08	0.1

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.53
# 0.51	0.53
# 0.52	0.52
# 0.5	0.52
# 0.52	0.53
# 0.51	0.53
# 0.51	0.52
# -- Mean --
# 0.51	0.53
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# # Q vs DDPG - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_none/q_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_a/q_vs_ddpg.csv")
    df_shock_b = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_b/q_vs_ddpg.csv")
    df_shock_c = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_c/q_vs_ddpg.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.77
# 1.68	1.75
# 1.68	1.76
# 1.68	1.72
# 1.68	1.84
# 1.68	1.8
# 1.68	1.75
# -- Mean --
# 1.68	1.77
# -- St. Dev --
# 0.0	0.04

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.75	0.12
# 0.67	0.13
# 0.7	0.14
# 0.56	0.16
# 1.01	0.02
# 0.88	0.09
# 0.69	0.15
# -- Mean --
# 0.75	0.12
# -- St. Dev --
# 0.15	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.65
# 0.45	0.61
# 0.46	0.63
# 0.45	0.54
# 0.46	0.81
# 0.47	0.73
# 0.47	0.62
# -- Mean --
# 0.46	0.66
# -- St. Dev --
# 0.01	0.09

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.73
# 1.68	1.72
# 1.69	1.77
# 1.69	1.77
# 1.68	1.75
# 1.68	1.77
# 1.69	1.76
# -- Mean --
# 1.69	1.75
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.88	-2.17
# -1.0	-2.15
# -0.44	-2.2
# -0.66	-2.37
# -0.92	-2.57
# -0.76	-2.61
# -0.68	-2.25
# -- Mean --
# -0.76	-2.33
# -- St. Dev --
# 0.19	0.19

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.36	-0.2
# -0.38	-0.23
# -0.36	-0.08
# -0.37	-0.09
# -0.44	-0.18
# -0.45	-0.12
# -0.36	-0.13
# -- Mean --
# -0.39	-0.15
# -- St. Dev --
# 0.04	0.06

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.79
# 1.68	1.78
# 1.69	1.85
# 1.68	1.76
# 1.68	1.75
# 1.68	1.81
# 1.68	1.77
# -- Mean --
# 1.68	1.79
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.78	-0.13
# 0.72	-0.16
# 1.01	-0.19
# 0.63	-0.11
# 0.56	-0.08
# 0.81	-0.24
# 0.64	-0.18
# -- Mean --
# 0.74	-0.16
# -- St. Dev --
# 0.15	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.36	0.63
# 0.35	0.61
# 0.37	0.76
# 0.36	0.56
# 0.35	0.52
# 0.34	0.68
# 0.35	0.57
# -- Mean --
# 0.35	0.62
# -- St. Dev --
# 0.01	0.08

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.77
# 1.68	1.71
# 1.69	1.74
# 1.68	1.73
# 1.68	1.69
# 1.68	1.72
# 1.69	1.74
# -- Mean --
# 1.68	1.73
# -- St. Dev --
# 0.01	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -1.74	-3.94
# -2.9	-4.23
# -2.07	-3.86
# -2.39	-3.88
# -2.43	-3.47
# -2.49	-3.79
# -1.7	-3.44
# -- Mean --
# -2.25	-3.8
# -- St. Dev --
# 0.43	0.27

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.82	-0.53
# -0.9	-0.81
# -0.8	-0.6
# -0.86	-0.67
# -0.78	-0.76
# -0.81	-0.68
# -0.75	-0.56
# -- Mean --
# -0.82	-0.66
# -- St. Dev --
# 0.05	0.1

# %% [markdown]
# # Q vs DDPG - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_none/q_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_a/q_vs_ddpg.csv")
    df_shock_b = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_b/q_vs_ddpg.csv")
    df_shock_c = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_c/q_vs_ddpg.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.11
# 1.13	1.12
# 1.12	1.15
# 1.12	1.14
# 1.12	1.15
# 1.11	1.12
# 1.12	1.16
# -- Mean --
# 1.12	1.14
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.41	0.39
# 0.45	0.42
# 0.57	0.4
# 0.55	0.39
# 0.6	0.38
# 0.43	0.38
# 0.63	0.38
# -- Mean --
# 0.52	0.39
# -- St. Dev --
# 0.09	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.45
# 0.5	0.49
# 0.49	0.6
# 0.48	0.58
# 0.47	0.62
# 0.46	0.47
# 0.48	0.65
# -- Mean --
# 0.48	0.55
# -- St. Dev --
# 0.01	0.08

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.12
# 1.12	1.14
# 1.12	1.13
# 1.12	1.1
# 1.13	1.14
# 1.12	1.15
# 1.12	1.13
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.42
# 0.5	0.46
# 0.5	0.41
# 0.37	0.43
# 0.53	0.44
# 0.54	0.45
# 0.52	0.41
# -- Mean --
# 0.49	0.43
# -- St. Dev --
# 0.06	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.47
# 0.5	0.55
# 0.49	0.52
# 0.49	0.4
# 0.51	0.56
# 0.49	0.6
# 0.49	0.54
# -- Mean --
# 0.49	0.52
# -- St. Dev --
# 0.01	0.07

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.12
# 1.13	1.1
# 1.12	1.17
# 1.12	1.16
# 1.12	1.12
# 1.12	1.11
# 1.12	1.13
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.38	0.48
# 0.34	0.46
# 0.69	0.38
# 0.6	0.4
# 0.46	0.38
# 0.4	0.37
# 0.46	0.42
# -- Mean --
# 0.48	0.41
# -- St. Dev --
# 0.13	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.48
# 0.5	0.41
# 0.5	0.69
# 0.49	0.63
# 0.49	0.48
# 0.47	0.42
# 0.48	0.52
# -- Mean --
# 0.49	0.52
# -- St. Dev --
# 0.01	0.11

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.13
# 1.12	1.14
# 1.13	1.12
# 1.13	1.11
# 1.13	1.13
# 1.12	1.17
# 1.12	1.12
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.42
# 0.56	0.43
# 0.54	0.38
# 0.42	0.5
# 0.64	0.32
# 0.58	0.54
# 0.52	0.37
# -- Mean --
# 0.54	0.42
# -- St. Dev --
# 0.07	0.08

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.53
# 0.49	0.56
# 0.51	0.49
# 0.51	0.46
# 0.51	0.53
# 0.5	0.7
# 0.5	0.48
# -- Mean --
# 0.5	0.54
# -- St. Dev --
# 0.01	0.08

# %% [markdown]
# # Q vs DDPG - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_none/q_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_a/q_vs_ddpg.csv")
    df_shock_b = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_b/q_vs_ddpg.csv")
    df_shock_c = pd.read_csv(f"./q_vs_ddpg/results/run_{i}/shock_c/q_vs_ddpg.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.45
# 0.46	0.46
# 0.46	0.47
# 0.46	0.47
# 0.46	0.46
# 0.46	0.46
# 0.46	0.47
# -- Mean --
# 0.46	0.46
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.01	0.04
# 0.04	0.02
# 0.05	0.02
# 0.06	0.01
# 0.03	0.03
# 0.04	0.02
# 0.06	0.02
# -- Mean --
# 0.04	0.02
# -- St. Dev --
# 0.02	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.32
# 0.47	0.48
# 0.5	0.55
# 0.48	0.61
# 0.48	0.4
# 0.48	0.49
# 0.49	0.6
# -- Mean --
# 0.48	0.49
# -- St. Dev --
# 0.01	0.11

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# -- Mean --
# 0.46	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.7	0.72
# 0.73	0.71
# 0.7	0.72
# 0.7	0.68
# 0.71	0.72
# 0.67	0.73
# 0.73	0.65
# -- Mean --
# 0.71	0.7
# -- St. Dev --
# 0.02	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.54
# 0.5	0.57
# 0.5	0.61
# 0.51	0.59
# 0.5	0.65
# 0.5	0.58
# 0.5	0.54
# -- Mean --
# 0.5	0.58
# -- St. Dev --
# 0.01	0.04

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.45
# 0.46	0.46
# 0.46	0.46
# 0.46	0.46
# 0.46	0.47
# 0.46	0.47
# 0.46	0.46
# -- Mean --
# 0.46	0.46
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.08	-0.07
# 0.06	0.01
# 0.08	-0.01
# 0.06	0.0
# 0.05	-0.02
# -0.01	0.03
# 0.08	0.02
# -- Mean --
# 0.06	-0.01
# -- St. Dev --
# 0.03	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.36
# 0.48	0.45
# 0.49	0.46
# 0.48	0.39
# 0.49	0.61
# 0.49	0.59
# 0.48	0.45
# -- Mean --
# 0.48	0.47
# -- St. Dev --
# 0.01	0.09

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.46	0.47
# 0.46	0.46
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.46	0.47
# 0.47	0.47
# -- Mean --
# 0.46	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.39	1.24
# 1.32	1.25
# 1.6	0.95
# 1.1	1.28
# 1.07	1.36
# 1.22	1.31
# 1.39	1.15
# -- Mean --
# 1.3	1.22
# -- St. Dev --
# 0.19	0.14

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.6
# 0.5	0.46
# 0.5	0.61
# 0.5	0.57
# 0.51	0.56
# 0.49	0.56
# 0.52	0.57
# -- Mean --
# 0.5	0.56
# -- St. Dev --
# 0.01	0.05

# %% [markdown]
# # PSO vs PSO - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_none/pso_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_a/pso_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_b/pso_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_c/pso_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # PSO vs PSO - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_none/pso_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_a/pso_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_b/pso_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_c/pso_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # PSO vs PSO - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_none/pso_vs_pso.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_a/pso_vs_pso_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_b/pso_vs_pso_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_pso/results/run_{i}/shock_c/pso_vs_pso_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # PSO vs DQN - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_none/pso_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_a/pso_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_b/pso_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_c/pso_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.68
# 1.69	1.68
# 1.69	1.68
# 1.69	1.68
# 1.69	1.68
# 1.69	1.68
# 1.69	1.68
# -- Mean --
# 1.69	1.68
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.63	0.5
# 0.63	0.5
# 0.62	0.5
# 0.62	0.5
# 0.63	0.5
# 0.63	0.5
# 0.62	0.5
# -- Mean --
# 0.63	0.5
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.47
# 0.48	0.47
# 0.48	0.46
# 0.48	0.46
# 0.48	0.47
# 0.48	0.47
# 0.48	0.47
# -- Mean --
# 0.48	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# -- Mean --
# 1.69	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.89	-1.38
# -0.83	-1.32
# -0.76	-1.28
# -0.66	-1.15
# -0.98	-1.46
# -0.78	-1.3
# -0.73	-1.23
# -- Mean --
# -0.8	-1.3
# -- St. Dev --
# 0.11	0.1

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.39	-0.39
# -0.36	-0.36
# -0.35	-0.35
# -0.34	-0.34
# -0.4	-0.4
# -0.36	-0.36
# -0.35	-0.35
# -- Mean --
# -0.36	-0.36
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.69	1.69
# 1.69	1.68
# 1.69	1.69
# 1.69	1.68
# 1.69	1.68
# 1.69	1.69
# -- Mean --
# 1.69	1.69
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.32
# 0.51	0.36
# 0.51	0.36
# 0.48	0.32
# 0.5	0.31
# 0.53	0.35
# 0.5	0.33
# -- Mean --
# 0.5	0.34
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.37	0.36
# 0.37	0.36
# 0.37	0.36
# 0.37	0.36
# 0.37	0.36
# 0.38	0.36
# 0.37	0.36
# -- Mean --
# 0.37	0.36
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# 1.69	1.69
# -- Mean --
# 1.69	1.69
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -1.82	-2.72
# -1.88	-2.41
# -1.45	-2.1
# -1.7	-2.58
# -1.57	-2.58
# -2.03	-2.41
# -1.96	-2.42
# -- Mean --
# -1.77	-2.46
# -- St. Dev --
# 0.21	0.2

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.82	-0.8
# -0.76	-0.76
# -0.73	-0.72
# -0.75	-0.74
# -0.74	-0.74
# -0.78	-0.76
# -0.82	-0.81
# -- Mean --
# -0.77	-0.76
# -- St. Dev --
# 0.04	0.03

# %% [markdown]
# # PSO vs DQN - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_none/pso_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_a/pso_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_b/pso_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_c/pso_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.14	1.12
# 1.14	1.12
# 1.14	1.12
# 1.14	1.12
# 1.14	1.12
# 1.14	1.12
# 1.14	1.12
# -- Mean --
# 1.14	1.12
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.54
# 0.48	0.54
# 0.48	0.54
# 0.47	0.54
# 0.48	0.54
# 0.47	0.54
# 0.47	0.54
# -- Mean --
# 0.48	0.54
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.57	0.49
# 0.57	0.49
# 0.57	0.49
# 0.57	0.49
# 0.57	0.49
# 0.57	0.49
# 0.57	0.49
# -- Mean --
# 0.57	0.49
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# -- Mean --
# 1.14	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.54	0.52
# 0.52	0.54
# 0.53	0.53
# 0.52	0.54
# 0.51	0.55
# 0.53	0.53
# 0.55	0.5
# -- Mean --
# 0.53	0.53
# -- St. Dev --
# 0.01	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.57	0.52
# 0.57	0.53
# 0.57	0.52
# 0.57	0.53
# 0.57	0.52
# 0.57	0.52
# 0.57	0.52
# -- Mean --
# 0.57	0.52
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# -- Mean --
# 1.14	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.51
# 0.56	0.48
# 0.54	0.5
# 0.54	0.5
# 0.47	0.56
# 0.55	0.48
# 0.47	0.57
# -- Mean --
# 0.52	0.51
# -- St. Dev --
# 0.04	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.57	0.51
# 0.57	0.51
# 0.57	0.51
# 0.57	0.51
# 0.57	0.5
# 0.57	0.51
# 0.57	0.51
# -- Mean --
# 0.57	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# 1.14	1.13
# -- Mean --
# 1.14	1.13
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.59
# 0.53	0.54
# 0.55	0.51
# 0.58	0.5
# 0.6	0.47
# 0.52	0.55
# 0.52	0.55
# -- Mean --
# 0.54	0.53
# -- St. Dev --
# 0.04	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.57	0.54
# 0.57	0.53
# 0.57	0.53
# 0.57	0.53
# 0.57	0.53
# 0.57	0.53
# 0.57	0.53
# -- Mean --
# 0.57	0.53
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# # PSO vs DQN - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_none/pso_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_a/pso_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_b/pso_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_dqn/results/run_{i}/shock_c/pso_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.08	-0.02
# 0.08	-0.02
# 0.08	-0.01
# 0.08	-0.02
# 0.08	-0.02
# 0.08	-0.02
# 0.08	-0.02
# -- Mean --
# 0.08	-0.02
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.16	0.51
# 0.16	0.52
# 0.16	0.51
# 0.16	0.52
# 0.16	0.51
# 0.16	0.51
# 0.16	0.51
# -- Mean --
# 0.16	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.65	0.65
# 0.65	0.68
# 0.64	0.66
# 0.67	0.7
# 0.63	0.66
# 0.62	0.7
# 0.66	0.7
# -- Mean --
# 0.65	0.68
# -- St. Dev --
# 0.02	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.16	0.53
# 0.16	0.53
# 0.16	0.53
# 0.16	0.52
# 0.16	0.52
# 0.16	0.53
# 0.16	0.53
# -- Mean --
# 0.16	0.53
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.47
# 0.44	0.46
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.03	0.02
# 0.14	-0.06
# 0.06	0.01
# 0.06	0.04
# 0.13	-0.04
# 0.06	-0.01
# 0.09	-0.01
# -- Mean --
# 0.08	-0.01
# -- St. Dev --
# 0.04	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.16	0.52
# 0.16	0.51
# 0.16	0.51
# 0.16	0.51
# 0.16	0.51
# 0.16	0.51
# 0.16	0.51
# -- Mean --
# 0.16	0.51
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.04	1.23
# 1.07	1.11
# 1.02	1.16
# 1.17	1.22
# 1.19	1.13
# 1.09	1.19
# 1.07	1.09
# -- Mean --
# 1.09	1.16
# -- St. Dev --
# 0.06	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.16	0.53
# 0.16	0.53
# 0.16	0.53
# 0.16	0.53
# 0.16	0.53
# 0.16	0.52
# 0.16	0.53
# -- Mean --
# 0.16	0.53
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# # PSO vs DDPG - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_none/pso_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_a/pso_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_b/pso_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_c/pso_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.59
# 1.67	1.64
# 1.68	1.65
# 1.68	1.62
# 1.67	1.65
# 1.68	1.6
# 1.67	1.66
# -- Mean --
# 1.67	1.63
# -- St. Dev --
# 0.01	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.22	0.29
# 0.42	0.21
# 0.47	0.2
# 0.33	0.24
# 0.45	0.19
# 0.25	0.26
# 0.51	0.17
# -- Mean --
# 0.38	0.22
# -- St. Dev --
# 0.11	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.26
# 0.44	0.37
# 0.45	0.39
# 0.45	0.32
# 0.44	0.38
# 0.45	0.28
# 0.44	0.41
# -- Mean --
# 0.44	0.34
# -- St. Dev --
# 0.01	0.06

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.58
# 1.67	1.62
# 1.67	1.55
# 1.68	1.59
# 1.67	1.59
# 1.67	1.56
# 1.67	1.57
# -- Mean --
# 1.67	1.58
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.2	-2.16
# -1.68	-2.13
# -2.22	-1.73
# -2.14	-1.98
# -2.28	-2.24
# -2.12	-1.85
# -2.04	-1.76
# -- Mean --
# -2.1	-1.98
# -- St. Dev --
# 0.2	0.2

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.44	-0.74
# -0.44	-0.61
# -0.41	-0.81
# -0.42	-0.72
# -0.44	-0.72
# -0.4	-0.75
# -0.41	-0.74
# -- Mean --
# -0.42	-0.73
# -- St. Dev --
# 0.02	0.06

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.63
# 1.67	1.57
# 1.67	1.64
# 1.67	1.64
# 1.67	1.61
# 1.67	1.63
# 1.67	1.62
# -- Mean --
# 1.67	1.62
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.22	-0.05
# -0.07	0.07
# 0.27	-0.05
# 0.28	-0.07
# 0.1	0.01
# 0.22	0.03
# 0.22	0.0
# -- Mean --
# 0.18	-0.01
# -- St. Dev --
# 0.12	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.32	0.24
# 0.33	0.09
# 0.32	0.25
# 0.32	0.26
# 0.32	0.17
# 0.34	0.22
# 0.32	0.22
# -- Mean --
# 0.32	0.21
# -- St. Dev --
# 0.01	0.06

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.67	1.67
# 1.66	1.55
# 1.67	1.61
# 1.67	1.64
# 1.67	1.6
# 1.66	1.58
# 1.67	1.61
# -- Mean --
# 1.67	1.61
# -- St. Dev --
# 0.0	0.04

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.24	-3.81
# -4.13	-3.74
# -3.05	-3.88
# -2.67	-3.96
# -3.35	-3.59
# -4.11	-4.36
# -3.17	-3.96
# -- Mean --
# -3.25	-3.9
# -- St. Dev --
# 0.7	0.24

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.88	-0.85
# -0.88	-1.28
# -0.86	-1.08
# -0.87	-0.96
# -0.81	-1.07
# -0.97	-1.28
# -0.84	-1.06
# -- Mean --
# -0.87	-1.08
# -- St. Dev --
# 0.05	0.16

# %% [markdown]
# # PSO vs DDPG - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_none/pso_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_a/pso_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_b/pso_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_c/pso_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.12
# 1.13	1.11
# 1.13	1.13
# 1.13	1.12
# 1.13	1.13
# 1.13	1.15
# 1.13	1.13
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.44
# 0.43	0.45
# 0.54	0.43
# 0.49	0.44
# 0.52	0.44
# 0.6	0.44
# 0.54	0.44
# -- Mean --
# 0.51	0.44
# -- St. Dev --
# 0.06	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.53	0.47
# 0.53	0.44
# 0.52	0.53
# 0.53	0.49
# 0.53	0.52
# 0.54	0.59
# 0.53	0.54
# -- Mean --
# 0.53	0.51
# -- St. Dev --
# 0.01	0.05

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.12
# 1.12	1.12
# 1.12	1.12
# 1.13	1.15
# 1.12	1.12
# 1.13	1.15
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.54	0.41
# 0.51	0.42
# 0.44	0.45
# 0.47	0.43
# 0.57	0.47
# 0.49	0.44
# 0.6	0.45
# -- Mean --
# 0.52	0.44
# -- St. Dev --
# 0.06	0.02

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.53
# 0.51	0.49
# 0.49	0.46
# 0.5	0.47
# 0.51	0.6
# 0.49	0.5
# 0.52	0.61
# -- Mean --
# 0.5	0.52
# -- St. Dev --
# 0.01	0.06

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.12
# 1.13	1.13
# 1.13	1.14
# 1.13	1.08
# 1.13	1.14
# 1.13	1.12
# -- Mean --
# 1.13	1.12
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.47
# 0.47	0.44
# 0.55	0.4
# 0.57	0.44
# 0.33	0.43
# 0.5	0.49
# 0.45	0.44
# -- Mean --
# 0.48	0.44
# -- St. Dev --
# 0.08	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.53	0.51
# 0.51	0.48
# 0.51	0.52
# 0.53	0.57
# 0.52	0.34
# 0.53	0.55
# 0.52	0.46
# -- Mean --
# 0.52	0.49
# -- St. Dev --
# 0.01	0.08

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.14
# 1.13	1.15
# 1.12	1.12
# 1.13	1.17
# 1.13	1.16
# 1.13	1.11
# 1.12	1.1
# -- Mean --
# 1.13	1.14
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.58	0.42
# 0.5	0.55
# 0.56	0.36
# 0.63	0.48
# 0.68	0.4
# 0.52	0.38
# 0.36	0.5
# -- Mean --
# 0.55	0.44
# -- St. Dev --
# 0.1	0.07

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.55
# 0.52	0.59
# 0.49	0.48
# 0.53	0.66
# 0.51	0.62
# 0.51	0.46
# 0.5	0.42
# -- Mean --
# 0.51	0.54
# -- St. Dev --
# 0.01	0.09

# %% [markdown]
# # PSO vs DDPG - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_none/pso_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_a/pso_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_b/pso_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./pso_vs_ddpg/results/run_{i}/shock_c/pso_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# 0.44	0.47
# 0.44	0.46
# 0.44	0.46
# -- Mean --
# 0.44	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.06	-0.03
# 0.06	-0.03
# 0.06	-0.03
# 0.06	-0.03
# 0.08	-0.04
# 0.06	-0.03
# 0.07	-0.04
# -- Mean --
# 0.06	-0.03
# -- St. Dev --
# 0.01	0.0

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.16	0.43
# 0.16	0.42
# 0.16	0.39
# 0.16	0.43
# 0.16	0.55
# 0.16	0.41
# 0.16	0.47
# -- Mean --
# 0.16	0.44
# -- St. Dev --
# 0.0	0.05

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.48
# 0.44	0.47
# 0.44	0.46
# 0.44	0.48
# 0.44	0.46
# 0.44	0.48
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.66	0.65
# 0.64	0.64
# 0.65	0.66
# 0.66	0.66
# 0.6	0.65
# 0.71	0.65
# 0.64	0.65
# -- Mean --
# 0.65	0.65
# -- St. Dev --
# 0.03	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.15	0.67
# 0.14	0.51
# 0.14	0.51
# 0.14	0.66
# 0.13	0.43
# 0.15	0.68
# 0.14	0.61
# -- Mean --
# 0.14	0.58
# -- St. Dev --
# 0.01	0.1

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.45
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# 0.44	0.46
# -- Mean --
# 0.44	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.05	-0.03
# 0.08	-0.03
# 0.11	-0.02
# 0.1	-0.03
# 0.08	-0.03
# 0.06	-0.08
# 0.05	0.05
# -- Mean --
# 0.08	-0.02
# -- St. Dev --
# 0.02	0.04

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.14	0.33
# 0.15	0.38
# 0.15	0.44
# 0.15	0.43
# 0.15	0.5
# 0.15	0.39
# 0.15	0.46
# -- Mean --
# 0.15	0.42
# -- St. Dev --
# 0.0	0.06

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.44	0.47
# 0.44	0.46
# 0.44	0.47
# 0.44	0.47
# 0.44	0.46
# 0.44	0.46
# 0.44	0.47
# -- Mean --
# 0.44	0.47
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.21	1.25
# 1.11	1.09
# 1.11	1.06
# 1.2	1.17
# 1.21	1.19
# 1.23	0.93
# 1.15	1.19
# -- Mean --
# 1.17	1.13
# -- St. Dev --
# 0.05	0.11

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.14	0.52
# 0.14	0.45
# 0.14	0.59
# 0.15	0.62
# 0.14	0.45
# 0.14	0.47
# 0.14	0.53
# -- Mean --
# 0.14	0.52
# -- St. Dev --
# 0.0	0.07

# %% [markdown]
# # DQN vs DQN - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # DQN vs DQN - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # DQN vs DQN - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_dqn/results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # DQN vs DDPG - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_none/dqn_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_a/dqn_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_b/dqn_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_c/dqn_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.68	1.77
# 1.68	1.84
# 1.69	1.83
# 1.68	1.79
# 1.68	1.78
# 1.68	1.79
# 1.68	1.79
# -- Mean --
# 1.68	1.8
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.76	0.12
# 1.01	0.03
# 0.97	0.05
# 0.82	0.1
# 0.79	0.11
# 0.85	0.09
# 0.84	0.09
# -- Mean --
# 0.86	0.08
# -- St. Dev --
# 0.09	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.66
# 0.47	0.81
# 0.47	0.79
# 0.47	0.7
# 0.47	0.68
# 0.47	0.71
# 0.46	0.7
# -- Mean --
# 0.47	0.72
# -- St. Dev --
# 0.0	0.06

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.81
# 1.69	1.76
# 1.69	1.79
# 1.69	1.77
# 1.69	1.77
# 1.69	1.74
# 1.69	1.8
# -- Mean --
# 1.69	1.78
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.09	-2.54
# -0.59	-2.29
# -0.37	-2.49
# -0.37	-2.19
# -0.65	-2.42
# -0.93	-2.21
# -0.27	-2.51
# -- Mean --
# -0.47	-2.38
# -- St. Dev --
# 0.28	0.15

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.38	0.05
# -0.37	-0.1
# -0.38	-0.01
# -0.34	-0.05
# -0.38	-0.09
# -0.35	-0.19
# -0.37	0.02
# -- Mean --
# -0.37	-0.05
# -- St. Dev --
# 0.02	0.08

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.83
# 1.68	1.77
# 1.69	1.8
# 1.68	1.78
# 1.68	1.73
# 1.69	1.76
# 1.69	1.79
# -- Mean --
# 1.69	1.78
# -- St. Dev --
# 0.01	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.95	-0.22
# 0.65	-0.12
# 0.77	-0.19
# 0.67	-0.14
# 0.47	-0.02
# 0.65	-0.1
# 0.72	-0.17
# -- Mean --
# 0.7	-0.14
# -- St. Dev --
# 0.15	0.07

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.37	0.72
# 0.36	0.58
# 0.36	0.64
# 0.36	0.59
# 0.36	0.47
# 0.37	0.56
# 0.36	0.62
# -- Mean --
# 0.36	0.6
# -- St. Dev --
# 0.0	0.08

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.69	1.69
# 1.69	1.7
# 1.69	1.68
# 1.69	1.73
# 1.69	1.71
# 1.69	1.69
# 1.69	1.78
# -- Mean --
# 1.69	1.71
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -2.68	-3.64
# -2.7	-3.43
# -2.79	-3.52
# -2.13	-3.71
# -2.84	-3.91
# -2.83	-3.74
# -1.23	-4.04
# -- Mean --
# -2.46	-3.71
# -- St. Dev --
# 0.59	0.21

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# -0.79	-0.8
# -0.78	-0.76
# -0.79	-0.83
# -0.75	-0.6
# -0.84	-0.77
# -0.81	-0.8
# -0.75	-0.41
# -- Mean --
# -0.79	-0.71
# -- St. Dev --
# 0.03	0.15

# %% [markdown]
# # DQN vs DDPG - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_none/dqn_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_a/dqn_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_b/dqn_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_c/dqn_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.12	1.13
# 1.12	1.12
# 1.12	1.16
# 1.12	1.13
# 1.12	1.09
# 1.12	1.15
# 1.12	1.16
# -- Mean --
# 1.12	1.13
# -- St. Dev --
# 0.0	0.03

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.41
# 0.45	0.42
# 0.61	0.4
# 0.5	0.42
# 0.31	0.43
# 0.56	0.41
# 0.6	0.4
# -- Mean --
# 0.5	0.41
# -- St. Dev --
# 0.1	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.49	0.51
# 0.49	0.48
# 0.49	0.63
# 0.5	0.53
# 0.5	0.36
# 0.5	0.58
# 0.5	0.62
# -- Mean --
# 0.5	0.53
# -- St. Dev --
# 0.01	0.09

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.12
# 1.13	1.15
# 1.13	1.11
# 1.13	1.13
# 1.13	1.12
# 1.13	1.14
# 1.13	1.17
# -- Mean --
# 1.13	1.13
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.45
# 0.57	0.44
# 0.43	0.44
# 0.48	0.45
# 0.46	0.44
# 0.54	0.46
# 0.64	0.47
# -- Mean --
# 0.51	0.45
# -- St. Dev --
# 0.07	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.53	0.5
# 0.52	0.59
# 0.53	0.44
# 0.52	0.51
# 0.52	0.49
# 0.52	0.57
# 0.52	0.69
# -- Mean --
# 0.52	0.54
# -- St. Dev --
# 0.0	0.08

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.09
# 1.13	1.11
# 1.12	1.09
# 1.13	1.11
# 1.13	1.1
# 1.13	1.14
# -- Mean --
# 1.13	1.11
# -- St. Dev --
# 0.0	0.02

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.48	0.43
# 0.32	0.44
# 0.44	0.4
# 0.38	0.37
# 0.37	0.44
# 0.4	0.4
# 0.49	0.45
# -- Mean --
# 0.41	0.42
# -- St. Dev --
# 0.06	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.5	0.53
# 0.5	0.37
# 0.5	0.45
# 0.5	0.37
# 0.5	0.43
# 0.51	0.42
# 0.5	0.56
# -- Mean --
# 0.5	0.45
# -- St. Dev --
# 0.0	0.07

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.13	1.13
# 1.13	1.14
# 1.13	1.16
# 1.13	1.13
# 1.13	1.15
# 1.13	1.15
# 1.13	1.13
# -- Mean --
# 1.13	1.14
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.51
# 0.51	0.49
# 0.58	0.5
# 0.6	0.35
# 0.58	0.46
# 0.5	0.55
# 0.57	0.41
# -- Mean --
# 0.54	0.47
# -- St. Dev --
# 0.05	0.07

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.53	0.53
# 0.53	0.54
# 0.53	0.64
# 0.53	0.5
# 0.53	0.59
# 0.53	0.6
# 0.53	0.53
# -- Mean --
# 0.53	0.56
# -- St. Dev --
# 0.0	0.05

# %% [markdown]
# # DQN vs DDPG - Linear

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_none/dqn_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_a/dqn_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_b/dqn_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./dqn_vs_ddpg/results/run_{i}/shock_c/dqn_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.47
# 0.47	0.46
# 0.47	0.47
# 0.47	0.47
# 0.47	0.47
# 0.47	0.46
# 0.47	0.47
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.05	0.02
# 0.02	0.04
# 0.06	0.02
# 0.05	0.02
# 0.05	0.02
# 0.04	0.03
# 0.05	0.02
# -- Mean --
# 0.05	0.02
# -- St. Dev --
# 0.01	0.01

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.51	0.59
# 0.51	0.39
# 0.51	0.64
# 0.51	0.53
# 0.51	0.53
# 0.52	0.47
# 0.52	0.56
# -- Mean --
# 0.51	0.53
# -- St. Dev --
# 0.0	0.08

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.46
# 0.47	0.47
# 0.47	0.47
# 0.47	0.46
# 0.47	0.47
# 0.47	0.47
# 0.47	0.46
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.0	0.01

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.74	0.68
# 0.75	0.71
# 0.66	0.75
# 0.67	0.68
# 0.67	0.74
# 0.71	0.71
# 0.69	0.68
# -- Mean --
# 0.7	0.71
# -- St. Dev --
# 0.04	0.03

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.46
# 0.52	0.58
# 0.52	0.61
# 0.52	0.43
# 0.53	0.55
# 0.52	0.62
# 0.52	0.51
# -- Mean --
# 0.52	0.54
# -- St. Dev --
# 0.0	0.07

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.47
# 0.47	0.46
# 0.47	0.46
# 0.46	0.46
# 0.47	0.46
# 0.47	0.46
# 0.47	0.47
# -- Mean --
# 0.47	0.46
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.07	-0.02
# 0.01	0.07
# 0.05	0.02
# 0.06	-0.02
# 0.12	-0.01
# 0.04	0.1
# 0.12	-0.01
# -- Mean --
# 0.07	0.02
# -- St. Dev --
# 0.04	0.05

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.52	0.57
# 0.51	0.41
# 0.51	0.5
# 0.51	0.42
# 0.51	0.49
# 0.51	0.48
# 0.51	0.51
# -- Mean --
# 0.51	0.48
# -- St. Dev --
# 0.0	0.05

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.47	0.47
# 0.47	0.46
# 0.47	0.46
# 0.47	0.47
# 0.47	0.47
# 0.47	0.47
# 0.47	0.47
# -- Mean --
# 0.47	0.47
# -- St. Dev --
# 0.0	0.0

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 1.18	1.32
# 1.16	1.07
# 1.11	1.29
# 1.14	1.37
# 1.4	1.05
# 1.13	1.34
# 1.06	1.28
# -- Mean --
# 1.17	1.25
# -- St. Dev --
# 0.11	0.13

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
# Out:
# 0.53	0.6
# 0.52	0.5
# 0.52	0.45
# 0.53	0.6
# 0.53	0.58
# 0.53	0.56
# 0.53	0.59
# -- Mean --
# 0.53	0.55
# -- St. Dev --
# 0.0	0.06

# %% [markdown]
# # DDPG vs DDPG - Logit

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_none/ddpg_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_a/ddpg_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_b/ddpg_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_c/ddpg_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[0, 1], df_shock_none.iat[0, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[0, 1], df_shock_a.iat[0, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[0, 1], df_shock_b.iat[0, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[0, 1], df_shock_c.iat[0, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[0, 5], df_shock_none.iat[0, 6]))
    deltas["shock_a"].append((df_shock_a.iat[0, 5], df_shock_a.iat[0, 6]))
    deltas["shock_b"].append((df_shock_b.iat[0, 5], df_shock_b.iat[0, 6]))
    deltas["shock_c"].append((df_shock_c.iat[0, 5], df_shock_c.iat[0, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[0, 7], df_shock_none.iat[0, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[0, 7], df_shock_a.iat[0, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[0, 7], df_shock_b.iat[0, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[0, 7], df_shock_c.iat[0, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # DDPG vs DDPG - Hotelling

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_none/ddpg_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_a/ddpg_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_b/ddpg_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_c/ddpg_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[1, 1], df_shock_none.iat[1, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[1, 1], df_shock_a.iat[1, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[1, 1], df_shock_b.iat[1, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[1, 1], df_shock_c.iat[1, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[1, 5], df_shock_none.iat[1, 6]))
    deltas["shock_a"].append((df_shock_a.iat[1, 5], df_shock_a.iat[1, 6]))
    deltas["shock_b"].append((df_shock_b.iat[1, 5], df_shock_b.iat[1, 6]))
    deltas["shock_c"].append((df_shock_c.iat[1, 5], df_shock_c.iat[1, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[1, 7], df_shock_none.iat[1, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[1, 7], df_shock_a.iat[1, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[1, 7], df_shock_b.iat[1, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[1, 7], df_shock_c.iat[1, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# # DDPG vs DDPG - Linear

# %%
model = 'linear' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_none/ddpg_vs_ddpg.csv")
    df_shock_a = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_a/ddpg_vs_ddpg_schemeA.csv")
    df_shock_b = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_b/ddpg_vs_ddpg_schemeB.csv")
    df_shock_c = pd.read_csv(f"./ddpg_vs_ddpg/results/run_{i}/shock_c/ddpg_vs_ddpg_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append((df_shock_none.iat[2, 1], df_shock_none.iat[2, 3]))
    avg_prices["shock_a"].append((df_shock_a.iat[2, 1], df_shock_a.iat[2, 3]))
    avg_prices["shock_b"].append((df_shock_b.iat[2, 1], df_shock_b.iat[2, 3]))
    avg_prices["shock_c"].append((df_shock_c.iat[2, 1], df_shock_c.iat[2, 3]))

    # deltas
    deltas["shock_none"].append((df_shock_none.iat[2, 5], df_shock_none.iat[2, 6]))
    deltas["shock_a"].append((df_shock_a.iat[2, 5], df_shock_a.iat[2, 6]))
    deltas["shock_b"].append((df_shock_b.iat[2, 5], df_shock_b.iat[2, 6]))
    deltas["shock_c"].append((df_shock_c.iat[2, 5], df_shock_c.iat[2, 6]))

    # rpdis
    rpdis["shock_none"].append((df_shock_none.iat[2, 7], df_shock_none.iat[2, 8]))
    rpdis["shock_a"].append((df_shock_a.iat[2, 7], df_shock_a.iat[2, 8]))
    rpdis["shock_b"].append((df_shock_b.iat[2, 7], df_shock_b.iat[2, 8]))
    rpdis["shock_c"].append((df_shock_c.iat[2, 7], df_shock_c.iat[2, 8]))

# %% [markdown]
# ## Shock None

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_none"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_none']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock A

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_a"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis['shock_a']

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock B

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_b"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ## Shock C

# %% [markdown]
# ### Average Prices

# %%
series = avg_prices["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### Deltas

# %%
series = deltas["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")

# %% [markdown]
# ### RPDIs

# %%
series = rpdis["shock_c"]

for x in series:
    print(f"{x[0]}\t{x[1]}")

print("-- Mean --")
print(f"{round(statistics.mean([x[0] for x in series]), 2)}\t{round(statistics.mean([x[1] for x in series]), 2)}")
print("-- St. Dev --")
print(f"{round(statistics.stdev([x[0] for x in series]), 2)}\t{round(statistics.stdev([x[1] for x in series]), 2)}")
