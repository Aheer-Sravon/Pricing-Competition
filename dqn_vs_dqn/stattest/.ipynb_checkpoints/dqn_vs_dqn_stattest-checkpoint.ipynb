# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
from scipy.stats import kruskal
import scikit_posthocs as sp

# %% [markdown]
# # Logit, Firm 1

# %% [markdown]
# ## Data Loading

# %%
model = 'logit' # row number = 0

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"../results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"../results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"../results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"../results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append(df_shock_none.iat[0, 1])
    avg_prices["shock_a"].append(df_shock_a.iat[0, 1])
    avg_prices["shock_b"].append(df_shock_b.iat[0, 1])
    avg_prices["shock_c"].append(df_shock_c.iat[0, 1])

    # deltas
    deltas["shock_none"].append(df_shock_none.iat[0, 5])
    deltas["shock_a"].append(df_shock_a.iat[0, 5])
    deltas["shock_b"].append(df_shock_b.iat[0, 5])
    deltas["shock_c"].append(df_shock_c.iat[0, 5])

    # rpdis
    rpdis["shock_none"].append(df_shock_none.iat[0, 7])
    rpdis["shock_a"].append(df_shock_a.iat[0, 7])
    rpdis["shock_b"].append(df_shock_b.iat[0, 7])
    rpdis["shock_c"].append(df_shock_c.iat[0, 7])

# %% [markdown]
# ## Kruskal-Wallis Test - Average Prices

# %%
h_stat, p_val = kruskal(
    avg_prices["shock_none"], 
    avg_prices["shock_a"], 
    avg_prices["shock_b"], 
    avg_prices["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on Average Prices")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on Average Prices
# H-statistic: 27.00, P-value: 0.00000589, epsilon_squared: 1.0000

# %% [markdown]
# ## Post-Hoc Testing - Average Prices

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        avg_prices["shock_none"], 
        avg_prices["shock_a"], 
        avg_prices["shock_b"], 
        avg_prices["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.001431  1.000000  0.001431
# 2  0.001431  1.000000  0.001431  1.000000
# 3  1.000000  0.001431  1.000000  0.001431
# 4  0.001431  1.000000  0.001431  1.000000

# %% [markdown]
# ## Kruskal-Wallis Test - Deltas

# %%
h_stat, p_val = kruskal(
    deltas["shock_none"], 
    deltas["shock_a"], 
    deltas["shock_b"], 
    deltas["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on Deltas")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on Deltas
# H-statistic: 25.53, P-value: 0.00001198, epsilon_squared: 0.9454

# %% [markdown]
# ## Post-Hoc Testing - Deltas

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        deltas["shock_none"], 
        deltas["shock_a"], 
        deltas["shock_b"], 
        deltas["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.006982  0.330329  0.000010
# 2  0.006982  1.000000  0.330329  0.330329
# 3  0.330329  0.330329  1.000000  0.006982
# 4  0.000010  0.330329  0.006982  1.000000

# %% [markdown]
# ## Kruskal-Wallis Test - RPDIs

# %%
h_stat, p_val = kruskal(
    rpdis["shock_none"], 
    rpdis["shock_a"], 
    rpdis["shock_b"], 
    rpdis["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on RPDIs")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on RPDIs
# H-statistic: 25.64, P-value: 0.00001135, epsilon_squared: 0.9496

# %% [markdown]
# ## Post-Hoc Testing - RPDIs

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        rpdis["shock_none"], 
        rpdis["shock_a"], 
        rpdis["shock_b"], 
        rpdis["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.006813  0.327975  0.000009
# 2  0.006813  1.000000  0.327975  0.327975
# 3  0.327975  0.327975  1.000000  0.006813
# 4  0.000009  0.327975  0.006813  1.000000

# %% [markdown]
# # Hotelling, Firm 1

# %% [markdown]
# ## Data Loading

# %%
model = 'hotelling' # row number = 1

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"../results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"../results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"../results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"../results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append(df_shock_none.iat[1, 1])
    avg_prices["shock_a"].append(df_shock_a.iat[1, 1])
    avg_prices["shock_b"].append(df_shock_b.iat[1, 1])
    avg_prices["shock_c"].append(df_shock_c.iat[1, 1])

    # deltas
    deltas["shock_none"].append(df_shock_none.iat[1, 5])
    deltas["shock_a"].append(df_shock_a.iat[1, 5])
    deltas["shock_b"].append(df_shock_b.iat[1, 5])
    deltas["shock_c"].append(df_shock_c.iat[1, 5])

    # rpdis
    rpdis["shock_none"].append(df_shock_none.iat[1, 7])
    rpdis["shock_a"].append(df_shock_a.iat[1, 7])
    rpdis["shock_b"].append(df_shock_b.iat[1, 7])
    rpdis["shock_c"].append(df_shock_c.iat[1, 7])

# %% [markdown]
# ## Kruskal-Wallis Test - Average Prices

# %%
h_stat, p_val = kruskal(
    avg_prices["shock_none"], 
    avg_prices["shock_a"], 
    avg_prices["shock_b"], 
    avg_prices["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on Average Prices")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on Average Prices
# H-statistic: 15.63, P-value: 0.00134925, epsilon_squared: 0.5789

# %% [markdown]
# ## Post-Hoc Testing - Average Prices

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        avg_prices["shock_none"], 
        avg_prices["shock_a"],
        avg_prices["shock_b"],
        avg_prices["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.367295  1.000000  0.004482
# 2  0.367295  1.000000  0.367295  0.367295
# 3  1.000000  0.367295  1.000000  0.004482
# 4  0.004482  0.367295  0.004482  1.000000

# %% [markdown]
# ## Kruskal-Wallis Test - Deltas

# %%
h_stat, p_val = kruskal(
    deltas["shock_none"], 
    deltas["shock_a"], 
    deltas["shock_b"], 
    deltas["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on Deltas")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on Deltas
# H-statistic: 1.27, P-value: 0.73618098, epsilon_squared: 0.0471

# %% [markdown]
# ## Post-Hoc Testing - Deltas

# %% [markdown]
# ## Kruskal-Wallis Test - RPDIs

# %%
h_stat, p_val = kruskal(
    rpdis["shock_none"], 
    rpdis["shock_a"], 
    rpdis["shock_b"], 
    rpdis["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on RPDIs")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on RPDIs
# H-statistic: 25.70, P-value: 0.00001101, epsilon_squared: 0.9519

# %% [markdown]
# ## Post-Hoc Testing - RPDIs

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        rpdis["shock_none"], 
        rpdis["shock_a"], 
        rpdis["shock_b"], 
        rpdis["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.003706  1.000000  0.000796
# 2  0.003706  1.000000  0.003706  1.000000
# 3  1.000000  0.003706  1.000000  0.000796
# 4  0.000796  1.000000  0.000796  1.000000

# %% [markdown]
# # Linear, Firm 1

# %% [markdown]
# ## Data Loading

# %%
model = 'linear' # row number = 2

avg_prices = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

deltas = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

rpdis = {
    "shock_none": [],
    "shock_a": [],
    "shock_b": [],
    "shock_c": []
}

for i in range(1, 8):
    # load the dataframes
    df_shock_none = pd.read_csv(f"../results/run_{i}/shock_none/dqn_vs_dqn.csv")
    df_shock_a = pd.read_csv(f"../results/run_{i}/shock_a/dqn_vs_dqn_schemeA.csv")
    df_shock_b = pd.read_csv(f"../results/run_{i}/shock_b/dqn_vs_dqn_schemeB.csv")
    df_shock_c = pd.read_csv(f"../results/run_{i}/shock_c/dqn_vs_dqn_schemeC.csv")

    # average prices
    avg_prices["shock_none"].append(df_shock_none.iat[2, 1])
    avg_prices["shock_a"].append(df_shock_a.iat[2, 1])
    avg_prices["shock_b"].append(df_shock_b.iat[2, 1])
    avg_prices["shock_c"].append(df_shock_c.iat[2, 1])

    # deltas
    deltas["shock_none"].append(df_shock_none.iat[2, 5])
    deltas["shock_a"].append(df_shock_a.iat[2, 5])
    deltas["shock_b"].append(df_shock_b.iat[2, 5])
    deltas["shock_c"].append(df_shock_c.iat[2, 5])

    # rpdis
    rpdis["shock_none"].append(df_shock_none.iat[2, 7])
    rpdis["shock_a"].append(df_shock_a.iat[2, 7])
    rpdis["shock_b"].append(df_shock_b.iat[2, 7])
    rpdis["shock_c"].append(df_shock_c.iat[2, 7])

# %% [markdown]
# ## Kruskal-Wallis Test - Average Prices

# %%
try:
    h_stat, p_val = kruskal(
        avg_prices["shock_none"], 
        avg_prices["shock_a"], 
        avg_prices["shock_b"], 
        avg_prices["shock_c"]
    )

    n = 4 * 7 # total number of observations across all groups
    epsilon_squared = h_stat / (n - 1)
    
    print("Kruskal-Wallis Test on Average Prices")
    print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
except ValueError:
    print("All numbers are identical in kruskal")
    
    print(f"avg_prices[\"shock_none\"] = {[float(x) for x in avg_prices["shock_none"]]}")
    print(f"avg_prices[\"shock_a\"] = {[float(x) for x in avg_prices["shock_a"]]}")
    print(f"avg_prices[\"shock_b\"] = {[float(x) for x in avg_prices["shock_b"]]}")
    print(f"avg_prices[\"shock_c\"] = {[float(x) for x in avg_prices["shock_c"]]}")
# Out:
# All numbers are identical in kruskal
# avg_prices["shock_none"] = [0.47, 0.47, 0.47, 0.47, 0.47, 0.47, 0.47]
# avg_prices["shock_a"] = [0.47, 0.47, 0.47, 0.47, 0.47, 0.47, 0.47]
# avg_prices["shock_b"] = [0.47, 0.47, 0.47, 0.47, 0.47, 0.47, 0.47]
# avg_prices["shock_c"] = [0.47, 0.47, 0.47, 0.47, 0.47, 0.47, 0.47]

# %% [markdown]
# There are are no differences between any of the average prices.

# %% [markdown]
# ## Post-Hoc Testing - Average Prices

# %% [markdown]
# Could not be performed.

# %% [markdown]
# ## Kruskal-Wallis Test - Deltas

# %%
h_stat, p_val = kruskal(
    deltas["shock_none"], 
    deltas["shock_a"], 
    deltas["shock_b"], 
    deltas["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on Deltas")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on Deltas
# H-statistic: 23.67, P-value: 0.00002934, epsilon_squared: 0.8765

# %% [markdown]
# ## Post-Hoc Testing - Deltas

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        deltas["shock_none"], 
        deltas["shock_a"], 
        deltas["shock_b"], 
        deltas["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.062021  0.817012  0.000418
# 2  0.062021  1.000000  0.043676  0.210582
# 3  0.817012  0.043676  1.000000  0.000187
# 4  0.000418  0.210582  0.000187  1.000000

# %% [markdown]
# ## Kruskal-Wallis Test - RPDIs

# %%
h_stat, p_val = kruskal(
    rpdis["shock_none"], 
    rpdis["shock_a"], 
    rpdis["shock_b"], 
    rpdis["shock_c"]
)
n = 4 * 7 # total number of observations across all groups
epsilon_squared = h_stat / (n - 1)

print("Kruskal-Wallis Test on RPDIs")
print(f"H-statistic: {h_stat:.2f}, P-value: {p_val:.8f}, epsilon_squared: {epsilon_squared:.4f}\n")
# Out:
# Kruskal-Wallis Test on RPDIs
# H-statistic: 18.54, P-value: 0.00034020, epsilon_squared: 0.6867

# %% [markdown]
# ## Post-Hoc Testing - RPDIs

# %%
dunn_matrix = sp.posthoc_dunn(
    [
        rpdis["shock_none"], 
        rpdis["shock_a"], 
        rpdis["shock_b"], 
        rpdis["shock_c"]
    ], p_adjust='holm'
)

print(dunn_matrix)
# Out:
#           1         2         3         4
# 1  1.000000  0.035484  0.442695  0.000645
# 2  0.035484  1.000000  0.193227  0.418121
# 3  0.442695  0.193227  1.000000  0.009498
# 4  0.000645  0.418121  0.009498  1.000000
